# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#Load the CSV file
file_path = 'SouthCalTS.csv'  
df = pd.read_csv(file_path, skiprows=7)

#Clean the data
df_clean = df[['first', 'second']]  # Select the relevant columns
df_clean.columns = ['Date', 'Precipitation']  # Rename columns for clarity
df_clean = df_clean.drop(0)  # Remove the first row which contains headers

#Convert 'Date' to datetime format and 'Precipitation' to numeric
df_clean['Date'] = pd.to_datetime(df_clean['Date'], format='%m/%d/%y %H:%M')
df_clean['Precipitation'] = pd.to_numeric(df_clean['Precipitation'], errors='coerce')

#Drop any rows with missing precipitation data
df_clean.dropna(subset=['Precipitation'], inplace=True)

#Set the 'Date' column as the index
df_clean.set_index('Date', inplace=True)

# %%
#Part 1: Decompose the time series into trend, seasonal, and residual components
decomposition = seasonal_decompose(df_clean['Precipitation'], model='additive', period=12)
decomposition.plot()
plt.show()

#Apply rolling mean to analyze long-term trends
df_clean['Rolling Mean'] = df_clean['Precipitation'].rolling(window=12).mean()

#Plot the original series with the rolling mean
plt.figure(figsize=(10, 6))
plt.plot(df_clean['Precipitation'], label='Original')
plt.plot(df_clean['Rolling Mean'], label='12-Month Rolling Mean', color='red')
plt.xlabel('Date')
plt.ylabel('Precipitation (mm/month)')
plt.title('Long-Term Trend of Precipitation in Southern California')
plt.legend()
plt.show()

# %%
#Part 2: Analyze seasonal patterns by grouping data by month
df_clean['Month'] = df_clean.index.month
monthly_avg = df_clean.groupby('Month')['Precipitation'].mean()

# Plot the average precipitation per month
plt.figure(figsize=(10, 6))
monthly_avg.plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Average Precipitation (mm/month)')
plt.title('Average Monthly Precipitation in Southern California (2003-2023)')
plt.show()

#Part 3: Identify anomalies using Z-score and Plot precipitation with anomalies highlighted
df_clean['Z-score'] = (df_clean['Precipitation'] - df_clean['Precipitation'].mean()) / df_clean['Precipitation'].std()

plt.figure(figsize=(10, 6))
plt.plot(df_clean.index, df_clean['Precipitation'], label='Precipitation')
plt.scatter(df_clean.index[df_clean['Z-score'] > 2], df_clean['Precipitation'][df_clean['Z-score'] > 2], color='red', label='Anomalies')
plt.xlabel('Date')
plt.ylabel('Precipitation (mm/month)')
plt.title('Precipitation with Anomalies Highlighted')
plt.legend()
plt.show()

# %%
import pymannkendall as mk
#Determines if they is an increase or decrease in precipitation over time

#Perform Mann-Kendall test to check for monotonic trends
result = mk.original_test(df_clean['Precipitation'])

#Print the test result
print(result)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.9815048954332499, z=0.02318225227931436, Tau=0.001037344398340249, s=30.0, var_s=1564893.3333333333, slope=0.00017592323551732824, intercept=12.51904271173792)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

#Create a new column for the numerical representation of the date
df_clean['Year'] = df_clean.index.year + df_clean.index.month / 12

#Prepare the data for linear regression
X = df_clean['Year'].values.reshape(-1, 1)  # Independent variable (Year)
y = df_clean['Precipitation'].values  # Dependent variable (Precipitation)

#Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

#Predict the trend line
df_clean['Trend Line'] = model.predict(X)

#Plot the original precipitation and the trend line
plt.figure(figsize=(10, 6))
plt.plot(df_clean.index, df_clean['Precipitation'], label='Precipitation')
plt.plot(df_clean.index, df_clean['Trend Line'], label='Trend Line', color='red')
plt.title('Precipitation with Linear Trend')
plt.xlabel('Year')
plt.ylabel('Precipitation (mm/month)')
plt.legend()
plt.show()

#Print the slope to check if it's negative
slope = model.coef_[0]
print(f"Slope of trend line: {slope}")
# Out:
# Slope of trend line: -0.1858729829465371
